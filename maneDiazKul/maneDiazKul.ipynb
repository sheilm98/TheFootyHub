# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
from mplsoccer import Radar, FontManager
# from sklearn.cluster import KMeans
import seaborn as sns
import mpld3

# %%
dfmane = pd.read_csv('mane.csv')
dfmane = dfmane.dropna()
dfmane
# Out:
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.40        85.0
# 1                     npxG   0.50        97.0
# 2              Shots Total   2.80        83.0
# 3                  Assists   0.15        37.0
# 4                       xA   0.14        35.0
# 5                  npxG+xA   0.64        91.0
# 6    Shot-Creating Actions   3.25        52.0
# 8         Passes Attempted  31.86        24.0
# 9        Pass Completion %  74.8%        40.0
# 10      Progressive Passes   3.20        45.0
# 11     Progressive Carries   6.39        58.0
# 12      Dribbles Completed   2.02        68.0
# 13       Touches (Att Pen)   8.36        97.0
# 14  Progressive Passes Rec  11.01        98.0
# 16               Pressures  14.33        30.0
# 17                 Tackles   1.25        39.0
# 18           Interceptions   0.60        18.0
# 19                  Blocks   1.17        53.0
# 20              Clearances   0.32        27.0
# 21             Aerials won   0.97        74.0

# %%
dfdiaz = pd.read_csv('diaz.csv')
dfdiaz = dfdiaz.dropna()
dfdiaz
# Out:
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.25        58.0
# 1                     npxG   0.11        15.0
# 2              Shots Total   1.52        22.0
# 3                  Assists   0.00         1.0
# 4                       xA   0.20        68.0
# 5                  npxG+xA   0.33        32.0
# 6    Shot-Creating Actions   2.03         6.0
# 8         Passes Attempted  28.35        14.0
# 9        Pass Completion %  77.7%        58.0
# 10      Progressive Passes   1.90        13.0
# 11     Progressive Carries   4.81        24.0
# 12      Dribbles Completed   2.91        93.0
# 13       Touches (Att Pen)   5.44        79.0
# 14  Progressive Passes Rec   6.33        49.0
# 16               Pressures  12.41        17.0
# 17                 Tackles   1.39        53.0
# 18           Interceptions   0.63        23.0
# 19                  Blocks   0.51         6.0
# 20              Clearances   0.25        18.0
# 21             Aerials won   1.01        77.0

# %%
dfkulusev = pd.read_csv('kulusev.csv')
dfkulusev = dfkulusev.dropna()
dfkulusev
# Out:
#                  Statistic Per 90  Percentile
# 0        Non-Penalty Goals   0.13        24.0
# 1                     npxG   0.16        28.0
# 2              Shots Total   1.73        31.0
# 3                  Assists   0.22        68.0
# 4                       xA   0.26        84.0
# 5                  npxG+xA   0.42        59.0
# 6    Shot-Creating Actions   3.50        64.0
# 8         Passes Attempted  30.68        21.0
# 9        Pass Completion %  77.2%        56.0
# 10      Progressive Passes   2.79        32.0
# 11     Progressive Carries   6.02        48.0
# 12      Dribbles Completed   1.42        40.0
# 13       Touches (Att Pen)   6.68        91.0
# 14  Progressive Passes Rec   8.15        85.0
# 16               Pressures  23.51        96.0
# 17                 Tackles   1.86        81.0
# 18           Interceptions   0.93        52.0
# 19                  Blocks   1.33        64.0
# 20              Clearances   0.18        10.0
# 21             Aerials won   1.06        77.0

# %%
def radar_mosaic(radar_height=0.915, title_height=0.06, figheight=14):
    """ Create a Radar chart flanked by a title and endnote axes.

    Parameters
    ----------
    radar_height: float, default 0.915
        The height of the radar axes in fractions of the figure height (default 91.5%).
    title_height: float, default 0.06
        The height of the title axes in fractions of the figure height (default 6%).
    figheight: float, default 14
        The figure height in inches.

    Returns
    -------
    fig : matplotlib.figure.Figure
    axs : dict[label, Axes]
    """
    if title_height + radar_height > 1:
        error_msg = 'Reduce one of the radar_height or title_height so the total is ≤ 1.'
        raise ValueError(error_msg)
    endnote_height = 1 - title_height - radar_height
    figwidth = figheight * radar_height
    figure, axes = plt.subplot_mosaic([['title'], ['radar'], ['endnote']],
                                      gridspec_kw={'height_ratios': [title_height, radar_height,
                                                                     endnote_height],
                                                   # the grid takes up the whole of the figure 0-1
                                                   'bottom': 0, 'left': 0, 'top': 1,
                                                   'right': 1, 'hspace': 0},
                                      figsize=(figwidth, figheight))
    axes['title'].axis('off')
    axes['endnote'].axis('off')
    return figure, axes

# %%
radar = Radar(params, low, high,
              # whether to round any of the labels to integers instead of decimal places
              round_int=[False]*11,
              num_rings=4,  # the number of concentric circles (excluding center circle)
              # if the ring_width is more than the center_circle_radius then
              # the center circle radius will be wider than the width of the concentric circles
              ring_width=1, center_circle_radius=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18568/247986595.py in <module>
# ----> 1 radar = Radar(params, low, high,
#       2               # whether to round any of the labels to integers instead of decimal places
#       3               round_int=[False]*11,
#       4               num_rings=4,  # the number of concentric circles (excluding center circle)
#       5               # if the ring_width is more than the center_circle_radius then
#
# NameError: name 'params' is not defined

# %%
fig, ax = radar.setup_axis()  # format axis as a radar
rings_inner = radar.draw_circles(ax=ax, facecolor='#ffb2b2', edgecolor='#fc5f5f')  # draw circles
radar_output = radar.draw_radar(mane, ax=ax,
                                kwargs_radar={'facecolor': '#aa65b2'},
                                kwargs_rings={'facecolor': '#66d8ba'})  # draw the radar
radar_poly, rings_outer, vertices = radar_output
range_labels = radar.draw_range_labels(ax=ax, fontsize=15,
                                       fontproperties=robotto_thin.prop)  # draw the range labels
param_labels = radar.draw_param_labels(ax=ax, fontsize=15,
                                       fontproperties=robotto_regular.prop)  # draw the param labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18568/2178231043.py in <module>
# ----> 1 fig, ax = radar.setup_axis()  # format axis as a radar
#       2 rings_inner = radar.draw_circles(ax=ax, facecolor='#ffb2b2', edgecolor='#fc5f5f')  # draw circles
#       3 radar_output = radar.draw_radar(mane, ax=ax,
#       4                                 kwargs_radar={'facecolor': '#aa65b2'},
#       5                                 kwargs_rings={'facecolor': '#66d8ba'})  # draw the radar
#
# NameError: name 'radar' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18568/1971997806.py in <module>
#       2
#       3 # plot the radar
# ----> 4 radar.setup_axis(ax=axs['radar'], facecolor='None')
#       5 rings_inner = radar.draw_circles(ax=axs['radar'], facecolor='#28252c', edgecolor='#39353f', lw=1.5)
#       6 radar_output = radar.draw_radar(bruno_values, ax=axs['radar'],
#
# NameError: name 'radar' is not defined
